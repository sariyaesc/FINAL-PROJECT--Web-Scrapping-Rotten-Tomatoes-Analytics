# %%
import requests
from bs4 import BeautifulSoup
import datetime
from datetime import datetime

# %%
def obtener_contenido_pagina(url):
    respone=requests.get(url)
    return respone.text

def analizar_contenido_html(html):
    return BeautifulSoup(html,'html.parser')

# %%
data=[]
def procesar_pagina(soup):
    titulos=[]
    tomatoers=[] 
    audience_scores=[]
    estrenos=[]

    #titulos
    titulo_items=soup.find_all('span',{'data-qa': 'discovery-media-list-item-title'})
    
    for item in titulo_items:
        titulo=item.text.strip()
        titulos.append(titulo)

    #tomatoers
    tomatoers_items=soup.find_all('score-pairs')
    
    for item in tomatoers_items:
        valor_critic=item['criticsscore']
        tomatoers.append(valor_critic)

    tomatoers= [None if item == "" else item for item in tomatoers]
    
    #audience
    audience_score=soup.find_all('score-pairs')

    for item in audience_score:
        valor_audience=item['audiencescore']
        audience_scores.append(valor_audience)
    
    audience_scores= [None if item == "" else item for item in audience_scores]

    #estrenos
    estrenos_items=soup.find_all('span',{'data-qa':'discovery-media-list-item-start-date'})

    for item in estrenos_items:
        estreno=item.text.strip()
        estrenos.append(estreno)

    estrenos=[item.replace('Opened ', '') for item in estrenos]
    estrenos=[item.replace('Opens ', '') for item in estrenos]
    
    min_length = min(len(titulos), len(tomatoers), len(audience_scores), len(estrenos))

    for i in range(min_length):
        data.append({
            "Titles": titulos[i] if i < len(titulos) else None,
            "Critics Score": tomatoers[i]  if i < len(tomatoers) else None,
            "Audience Score": audience_scores[i]  if i < len(audience_scores) else None,
            "Premiere": estrenos[i] if i < len(estrenos) else None,
        })

    print(data)

# %%
url= "https://www.rottentomatoes.com/browse/movies_in_theaters/?page=4"
contenido_pagina = obtener_contenido_pagina(url)
soup = analizar_contenido_html(contenido_pagina)
procesar_pagina(soup)
# Out:
# [{'Titles': 'Mamamoo: My Con the Movie', 'Critics Score': None, 'Audience Score': '100', 'Premiere': 'Aug 09, 2023'}, {'Titles': 'Hunting for the Hag', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 09, 2023'}, {'Titles': 'Underdog', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 10, 2023'}, {'Titles': 'Jailer', 'Critics Score': None, 'Audience Score': '83', 'Premiere': 'Aug 10, 2023'}, {'Titles': 'Bholaa Shankar', 'Critics Score': None, 'Audience Score': '43', 'Premiere': 'Aug 10, 2023'}, {'Titles': 'Drum Corps International: Big, Loud & Live 18', 'Critics Score': None, 'Audience Score': '100', 'Premiere': 'Aug 10, 2023'}, {'Titles': 'Gran Turismo: Based on a True Story', 'Critics Score': '55', 'Audience Score': None, 'Premiere': 'Aug 25, 2023'}, {'Titles': 'The Last Voyage of the Demeter', 'Critics Score': '37', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Jules', 'Critics Score': '87', 'Audience Score': '80', 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Heart of Stone', 'Critics Score': '29', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Medusa Deluxe', 'Critics Score': '77', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'King on Screen', 'Critics Score': '83', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Aporia', 'Critics Score': '90', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Operation Napoleon', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'The Pod Generation', 'Critics Score': '40', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Go West', 'Critics Score': None, 'Audience Score': '82', 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Inside Man', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'King Coal', 'Critics Score': '88', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Between Two Worlds', 'Critics Score': '79', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Match Me If You Can', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Gadar 2', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': '3 Days in Malay', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'The Monkey King', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': "Aurora's Sunrise", 'Critics Score': '100', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'The Eternal Memory', 'Critics Score': '93', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Senior Year: Love Never Fails', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'OMG 2', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'CHAAW: Chapter 1', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Love Life', 'Critics Score': '76', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'With This Light', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'One and Only', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Sound of the Police', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Mad Fate', 'Critics Score': '80', 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Caddy Hack', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Orisa', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 11, 2023'}, {'Titles': 'Ustaad', 'Critics Score': None, 'Audience Score': None, 'Premiere': 'Aug 12, 2023'}, {'Titles': 'Barbie', 'Critics Score': '88', 'Audience Score': '84', 'Premiere': 'Jul 21, 2023'}, {'Titles': 'Oppenheimer', 'Critics Score': '93', 'Audience Score': '91', 'Premiere':  ...

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#                               Titles Critics Score Audience Score  \
# 0          Mamamoo: My Con the Movie          None            100
# 1                Hunting for the Hag          None           None
# 2                           Underdog          None           None
# 3                             Jailer          None             83
# 4                     Bholaa Shankar          None             43
# ..                               ...           ...            ...
# 97                      Men of Deeds           100           None
# 98                  Growing Up Local          None           None
# 99         Miss Shetty Mr Polishetty          None           None
# 100  Rosemary & Sage Turn Back Thyme          None           None
# 101                    Corona Dhavan          None           None
#
#          Premiere
# 0    Aug 09, 2023
# 1    Aug 09, 2023
# 2    Aug 10, 2023
# 3    Aug 10, 2023
# 4    Aug 10, 2023
# ..            ...
# 97   Aug 04, 2023
# 98   Aug 04, 2023
# 99   Aug 04, 2023
# 100  Aug 04, 2023
# 101  Aug 04, 2023
#
# [102 rows x 4 columns]

# %%
import datetime

fecha_actual = datetime.datetime.now().strftime("%d-%m-%Y")

df.to_csv(f"dataset/On-Theaters-Rotten-Tomatoes-{fecha_actual}.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 5
#       1 import datetime
#       3 fecha_actual = datetime.datetime.now().strftime("%d-%m-%Y")
# ----> 5 df.to_csv(f"/On-Theaters-Rotten-Tomatoes-{fecha_actual}.csv", index=False)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '/On-Theaters-Rotten-Tomatoes-10-08-2023.csv'
